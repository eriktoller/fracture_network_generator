# %% [markdown]
# # Fracture Network Generator
# This program generates a fracture network using the following inputs:
# - number of fractures
# - axis limits for x and y
#
# The prgram was written by:
#
# Erik Toller, Department of Earth Sciences, Uppsala University, Sweden. erik.toller@geo.uu.se

# %% [markdown]
# ## Import Packages

# %%
import importlib
import gen_funcs as gf
importlib.reload(gf)
# Out:
# <module 'gen_funcs' from 'C:\\Users\\erito849\\python-course\\project\\project_git\\gen_funcs.py'>

# %% [markdown]
# ## User Input

# %%
print('Enter number of fractures:')
num = 1000 #input()
print('Enter axis limits as [xfrom xto yfrom yto]:')
xy_ax = [-1, 1, -1, 1] #input() 

print('Number of fractures: ' + str(num))
print('Axis limits: ' + str(xy_ax))
# Out:
# Enter number of fractures:
# Enter axis limits as [xfrom xto yfrom yto]:
# Number of fractures: 1000
# Axis limits: [-1, 1, -1, 1]

# %%
[sliderx, slidery,slidernum] = gf.input_func()

display(sliderx)
display(slidery)
display(slidernum)
# Out:
# FloatRangeSlider(value=(-1.0, 1.0), continuous_update=False, description='x-axis:', max=10.0, min=-10.0, reado…
# FloatRangeSlider(value=(-1.0, 1.0), continuous_update=False, description='y-axis:', max=10.0, min=-10.0, reado…
# IntSlider(value=1, continuous_update=False, description='Fractures:', max=10000, min=1)

# %%
x = sliderx.value
y = slidery.value
xy_ax = [x[0],x[1],y[0],y[1]]
num = slidernum.value

# %% [markdown]
# ## Generate the Fracture Network

# %%
[z1,z2] = gf.collect_frac(num, xy_ax)
# Out:
# IntProgress(value=0, description='Generating', max=1082)

# %% [markdown]
# ## Plot the Fracture Network

# %%
gf.plot_frac(z1, z2)
# Out:
# IntProgress(value=0, description='Plotting', max=1082)

# %% [markdown]
# ### Plot the Length Distribution

# %%
gf.plot_length(z1, z2)
